# %%
import numpy as np 
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier

# %%
x,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
x=pd.DataFrame(x, columns=[f'feature_{i}' for i in range(x.shape[1])])
y=pd.DataFrame(y,columns=["target" in y.shape])

# %%
x.head(5)
x.shape
# Out:
# (100, 5)

# %%
y.head(5)
y.shape
# Out:
# (100, 1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# 1. Define your input features (X) and true labels (y)

# 2. Initialize and train the Random Forest model
rf_model = RandomForestClassifier(n_estimators=5, random_state=42)
rf_model.fit(X, y)

# 3. Manual Prediction for a single data point
# Using the values from row 0 of your dataset as an example
new_data_point = np.array([[0.551380, -1.876815, -1.807618, -1.557932, -0.039809]])

manual_pred = rf_model.predict(new_data_point)
print(f"Manual Prediction for the specific point: {manual_pred[0]}")

# 4. Generate predictions for the entire dataset to check accuracy
predictions = rf_model.predict(X)
print(f"Random Forest Overall Accuracy: {accuracy_score(y, predictions):.2f}")
