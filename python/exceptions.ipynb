# %%
def check(x):
    try:
        if 10%x==0:
            return "divided"
    except Exception as e:
        print(e)

# %%
print(check(0))
# Out:
# integer division or modulo by zero
# None

# %%
if 10%0==0:
    print("divided")
print("my name is abbas")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 if 10%0==0:
#       2     print("divided")
#       3 print("my name is abbas")
#
# ZeroDivisionError: integer division or modulo by zero

# %%
try:
    if 10%0==0:
        print("divided")
except Exception as e:
    print ("the error is due to",e)        
print("my name is abbas")
# Out:
# the error is due to integer division or modulo by zero
# my name is abbas

# %%
try: 


    try:
        if 10/0:
            print("divide")

    except Exception as e :
        print(e)

    with open ("exm2.txt",mode='a') as f:
        f.write("hello how are you")

    with open ("exm2.txt",mode='r') as f:
        for i in f:
            print(i) 

except IOError as io:
    print(io)
# Out:
# division by zero
# hello how are youhello how are youhello how are you
