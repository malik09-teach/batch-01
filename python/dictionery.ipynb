# %%
dicti={}
print(type(dicti))
# Out:
# <class 'dict'>

# %%
dicti={"name":"abbas","Age":24,"edu":"BS"}

# %%
print(dicti)
# Out:
# {'name': 'abbas', 'Age': 23, 'edu': 'BS'}

# %%
dicti["abbas"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dicti["abbas"]
#
# KeyError: 'abbas'

# %%
for key,val in dicti.items():
    print(key,val)
# Out:
# name abbas
# Age 23
# edu BS

# %%
dicti.get("name")
# Out:
# 'abbas'

# %%
dicti.values()
# Out:
# dict_values(['abbas', 24, 'BS'])

# %%
dicti.keys()
# Out:
# dict_keys(['name', 'Age', 'edu'])

# %%
dicti.items()
# Out:
# dict_items([('name', 'abbas'), ('Age', 24), ('edu', 'BS')])

# %%
dicti["name"]="shoiab"

# %%
dicti.items()
# Out:
# dict_items([('name', 'shoiab'), ('Age', 24), ('edu', 'BS')])

# %%
dicti.pop("name")
# Out:
# 'shoiab'

# %%
dicti.items()
# Out:
# dict_items([('Age', 24), ('edu', 'BS')])

# %%
squre_number={x:x**3 for x in range(1,11)}

# %%
squre_number
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000}

# %%
import pandas as pd

# %%
data=pd.DataFrame(data=squre_number,columns=["so_no","sq_val"])

# %%
data
# Out:
# Empty DataFrame
# Columns: [so_no, sq_val]
# Index: []

# %%
user={"user1":{"name":"abbas","loc":"pesh"},
       "user2":{"name":"shoiab","loc":"multan"}
}

# %%
print(user["user1"])
# Out:
# {'name': 'abbas', 'loc': 'pesh'}

# %%
print(user["user2"])
# Out:
# {'name': 'shoiab', 'loc': 'multan'}

# %%
for key ,val in user.items():
    print(key,val)
# Out:
# user1 {'name': 'abbas', 'loc': 'pesh'}
# user2 {'name': 'shoiab', 'loc': 'multan'}
