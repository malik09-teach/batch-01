# %%
tuples=()

print(type(tuples))
# Out:
# <class 'tuple'>

# %%
tuples=(1,2,3,4,5)
tuples
# Out:
# (1, 2, 3, 4, 5)

# %%
tuples[0]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tuples[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup=([1,2,3,4,5],[[11,2,3,4,5]])

# %%
tup[1]=[1,2,3,4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tup[1]=[1,2,3,4]
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup
# Out:
# ([1, 2, 3, 4, 5], [[15, 2, 3, 4, 5]])

# %%
tup=([1,2,3,4,5],[[11,2,3,4,5]])

tup[1][0][0]=90

# %%
tup
# Out:
# ([1, 2, 3, 4, 5], [[90, 2, 3, 4, 5]])
