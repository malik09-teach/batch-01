# %%
"""w+,a,r"""
path="exmaple.txt"

with open (path,mode='w+') as file :
    file.write ("i am teacher \n") 
    file.write ("i am a teacher of ML \n") 
    file.write ("i am 24 yr old \n") 
    file.write ("i am master student \n")

# %%
with open (path,mode='r') as file :
    for row in file:
        print(row)
# Out:
# i am teacher
#
# i am a teacher of ML
#
# i am 24 yr old
#
# i am master student

# %%
with open (path,mode='w+') as file :
    file.write ("i am teacher \n")

# %%
with open (path,mode='r') as file :
    for row in file:
        print(row)
# Out:
# i am teacher

# %%
with open (path,mode='w') as file :
    file.write ("i am teacher \n") 
    file.write ("i am a teacher of ML \n") 
    file.write ("i am 24 yr old \n") 
    file.write ("i am master student \n")

# %%
with open (path,mode='r') as file :
    for row in file:
        print(row)
# Out:
# i am teacher
#
# i am a teacher of ML
#
# i am 24 yr old
#
# i am master student

# %%
with open (path,mode='w') as file :
    file.write ("i am teacher \n")

# %%
with open (path,mode='r') as file :
    for row in file:
        print(row)
# Out:
# i am teacher

# %%
with open (path,mode='w') as file :
    file.write ("i am teacher \n") 
    file.write ("i am a teacher of ML \n") 
    file.write ("i am 24 yr old \n") 
    file.write ("i am master student \n")

# %%
with open (path,mode='r') as file :
    for row in file:
        print(row)
# Out:
# i am teacher
#
# i am a teacher of ML
#
# i am 24 yr old
#
# i am master student

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 with open (path,mode='w+') as file :
# ----> 2     file.write ("1","i am teacher \n")
#       3     file.write ("2","i am a teacher of ML \n")
#
# TypeError: TextIOWrapper.write() takes exactly one argument (2 given)

# %%
with open (path,mode='r') as file :
    data=file.read()

# %%
data
# Out:
# 'i am teacher \ni am a teacher of ML \ni am 24 yr old \ni am master student \ni am teacher \ni am a teacher of ML \n'
