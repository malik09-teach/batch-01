# %%
import os

cd=os.getcwd()
print(f"we are in current {cd}")
# Out:
# we are in current d:\BATCH 01\batch-01\python

# %%
path="packeges"

os.mkdir(path)

# %%
os.path.exists("exma.txt")
# Out:
# False
