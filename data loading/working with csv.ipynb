# %%
import pandas as pd

# %%
data = pd.read_csv(
    "Exam_Score_Prediction.csv",
    converters={'sleep_quality': lambda x: 0 if x == 'poor' else x}
)

# %%
data.head(5)
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4             0       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5             0       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8             0       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
data.tail(5)
# Out:
#        student_id  age gender   course  study_hours  class_attendance  \
# 19995       19997   18  other      bba         6.50              71.3
# 19996       19998   18   male    b.com         3.71              41.6
# 19997       19999   19  other  diploma         7.88              68.2
# 19998       20000   19   male      bba         4.60              76.3
# 19999       20001   20   male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality study_method facility_rating  \
# 19995             yes          5.0          good   self-study             low
# 19996              no          5.9       average     coaching          medium
# 19997             yes          4.6          poor  group study             low
# 19998              no          6.1          good   self-study          medium
# 19999             yes          7.5          poor     coaching          medium
#
#       exam_difficulty  exam_score
# 19995            easy        86.5
# ...

# %%
data.sample(5)
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 11987       11988   24  female  diploma         4.39              41.4
# 6171         6172   19   other    b.com         6.24              41.2
# 1681         1682   17   other       ba         1.72              42.2
# 103           104   17    male      bba         7.00              80.6
# 18980       18981   21   other     b.sc         0.91              84.8
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# 11987             yes          6.5          good    group study
# 6171              yes          4.9       average  online videos
# 1681              yes          5.7          good          mixed
# 103               yes          9.6          poor    group study
# 18980              no          5.2          poor  online videos
#
#       facility_rating exam_difficulty  exam_score
# 11987            high            easy        76.1
# 6171           medium            easy        74.1
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  str
#  3   course            20000 non-null  str
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  str
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  str
#  9   study_method      20000 non-null  str
#  10  facility_rating   20000 non-null  str
#  11  exam_difficulty   20000 non-null  str
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), str(7)
# memory usage: 2.7 MB

# %%
data.describe()
# Out:
#          student_id           age   study_hours  class_attendance  \
# count  20000.000000  20000.000000  20000.000000      20000.000000
# mean   10000.504600     20.473300      4.007604         70.017365
# std     5773.654959      2.284458      2.308313         17.282262
# min        1.000000     17.000000      0.080000         40.600000
# 25%     5000.750000     18.000000      2.000000         55.100000
# 50%    10000.500000     20.000000      4.040000         69.900000
# 75%    15000.250000     22.000000      6.000000         85.000000
# max    20001.000000     24.000000      7.910000         99.400000
#
#        sleep_hours    exam_score
# count  20000.00000  20000.000000
# mean       7.00856     62.513225
# std        1.73209     18.908491
# min        4.10000     19.599000
# 25%        5.50000     48.800000
# 50%        7.00000     62.600000
# 75%        8.50000     76.300000
# max        9.90000    100.000000

# %%
data.shape
# Out:
# (20000, 13)

# %%
chunksdata=pd.read_csv('Exam_Score_Prediction.csv',chunksize=5000)

# %%
for i in chunksdata:
    print(i.shape)
# Out:
# (5000, 13)
# (5000, 13)
# (5000, 13)
# (5000, 13)

# %%
newdata=data.iloc[:5000,8:]

# %%
newdata.head()
# Out:
#   sleep_quality   study_method facility_rating exam_difficulty  exam_score
# 0          poor       coaching             low            hard        58.9
# 1       average  online videos          medium        moderate        54.8
# 2          poor       coaching            high        moderate        90.3
# 3       average  online videos             low        moderate        29.7
# 4          poor       coaching             low        moderate        43.7

# %%
newdata.shape
# Out:
# (5000, 5)

# %%
n_New_data=pd.read_csv("Exam_Score_Prediction.csv",usecols=['student_id','age','class_attendance','exam_score'],nrows=5000) #dtype={'class_attendance':'int64','exam_score':'int64'}

# %%
n_New_data['class_attendance'] = n_New_data['class_attendance'].astype('int64')


n_New_data['exam_score'] = n_New_data['exam_score'].astype('int64')

# %%
n_New_data.head()
# Out:
#    student_id  age  class_attendance  exam_score
# 0           1   17              92.9        58.9
# 1           2   23              64.8        54.8
# 2           3   22              76.8        90.3
# 3           4   20              48.4        29.7
# 4           5   20              71.6        43.7

# %%
n_New_data.shape
# Out:
# (5000, 4)

# %%
n_New_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        5000 non-null   int64
#  1   age               5000 non-null   int64
#  2   class_attendance  5000 non-null   int64
#  3   exam_score        5000 non-null   int64
# dtypes: int64(4)
# memory usage: 156.4 KB
