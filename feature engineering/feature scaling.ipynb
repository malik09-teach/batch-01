# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
iris=sns.load_dataset('iris')

# %%
iris.describe(())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_width'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
min_maxscal=MinMaxScaler()
Stand_scale=StandardScaler()

# %%
iris.iloc[:,:2]=min_maxscal.fit_transform(iris.iloc[:,:2])

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0      0.222222     0.625000     -1.340227    -1.315444  setosa
# 1      0.166667     0.416667     -1.340227    -1.315444  setosa
# 2      0.111111     0.500000     -1.397064    -1.315444  setosa
# 3      0.083333     0.458333     -1.283389    -1.315444  setosa
# 4      0.194444     0.666667     -1.340227    -1.315444  setosa

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_width'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 48       0.277778     0.708333           1.5          0.2      setosa
# 42       0.027778     0.500000           1.3          0.2      setosa
# 16       0.305556     0.791667           1.3          0.4      setosa
# 72       0.555556     0.208333           4.9          1.5  versicolor
# 100      0.555556     0.541667           6.0          2.5   virginica

# %%
iris.iloc[:,:4]=min_maxscal.fit_transform(iris.iloc[:,:4])

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 97       0.527778     0.375000      0.559322     0.500000  versicolor
# 114      0.416667     0.333333      0.694915     0.958333   virginica
# 140      0.666667     0.458333      0.779661     0.958333   virginica
# 55       0.388889     0.333333      0.593220     0.500000  versicolor
# 30       0.138889     0.458333      0.101695     0.041667      setosa

# %%
iris.iloc[:,:4]=Stand_scale.fit_transform(iris.iloc[:,:4])

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0     -0.900681     1.019004     -1.340227    -1.315444  setosa
# 1     -1.143017    -0.131979     -1.340227    -1.315444  setosa
# 2     -1.385353     0.328414     -1.397064    -1.315444  setosa
# 3     -1.506521     0.098217     -1.283389    -1.315444  setosa
# 4     -1.021849     1.249201     -1.340227    -1.315444  setosa

# %%
iris['petal_length'].describe()
# Out:
# count    1.500000e+02
# mean    -4.263256e-16
# std      1.003350e+00
# min     -1.567576e+00
# 25%     -1.226552e+00
# 50%      3.364776e-01
# 75%      7.627583e-01
# max      1.785832e+00
# Name: petal_length, dtype: float64

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_width'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
