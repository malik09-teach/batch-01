# %%
import pandas as pd 
import seaborn as sns

# %%
data= sns.load_dataset("titanic")

# %%
data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
data.shape
# Out:
# (891, 15)

# %%
data.duplicated().sum()
# Out:
# np.int64(107)

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (349, 5)

# %%
data=data.drop(['who'	,'adult_male',	'deck'],axis=1)

# %%
data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    embark_town alive  alone
# 0  Southampton    no  False
# 1    Cherbourg   yes  False
# 2  Southampton   yes   True
# 3  Southampton   yes  False
# ...

# %%
# non-destructive (returns a new DataFrame)
#data = data.drop(data.index[3:7])
# to reindex rows after dropping, uncomment:
data = data.drop(data.index[3:7]).reset_index(drop=True)
#data = data.drop(data.index[3:7], axis=0)

# or in-place
# data.drop(index=range(3,7), inplace=True)

# %%
data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  58.0      0      0  26.5500        S   First
# 4         0       3    male  20.0      0      0   8.0500        S   Third
# 5         0       3    male  39.0      1      5  31.2750        S   Third
# 6         0       3  female  14.0      0      0   7.8542        S   Third
# 7         1       2  female  55.0      0      0  16.0000        S  Second
# 8         0       3    male   2.0      4      1  29.1250        Q   Third
# 9         1       2    male   NaN      0      0  13.0000        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
from sklearn.model_selection import  train_test_split

# %%
data = data.drop(['sibsp','parch','fare','embarked','class','who','adult_male','deck','embark_town','alone'], axis=1, errors='ignore')

# %%
data.head()
# Out:
#    survived  pclass     sex   age alive
# 0         0       3    male  22.0    no
# 1         1       1  female  38.0   yes
# 2         1       3  female  26.0   yes
# 3         1       1  female  35.0   yes
# 4         0       3    male  35.0    no

# %%
x=data.iloc[:,1:]

y=data.iloc[:,:1]

# %%
x
# Out:
#      pclass     sex   age alive
# 0         3    male  22.0    no
# 1         1  female  38.0   yes
# 2         3  female  26.0   yes
# 3         1  female  35.0   yes
# 4         3    male  35.0    no
# ..      ...     ...   ...   ...
# 886       2    male  27.0    no
# 887       1  female  19.0   yes
# 888       3  female   NaN    no
# 889       1    male  26.0   yes
# 890       3    male  32.0    no
#
# [891 rows x 4 columns]

# %%
y
# Out:
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(
    x,
    y,
    test_size=0.20,
    random_state=42
    
)

# %%
xtrain
# Out:
#      pclass     sex   age alive
# 603       3    male   NaN    no
# 433       3    male  20.0    no
# 360       3  female   NaN   yes
# 355       3    male  35.0    no
# 81        3    male  24.0    no
# ..      ...     ...   ...   ...
# 106       3  female  17.0    no
# 270       3    male   7.0    no
# 860       3    male   NaN    no
# 435       2  female  28.0   yes
# 102       1    male  47.0    no
#
# [706 rows x 4 columns]

# %%
xtest
# Out:
#      pclass     sex   age alive
# 44        1  female  49.0   yes
# 806       3    male  30.5    no
# 720       2    male  25.0    no
# 660       3    male  43.0    no
# 878       2    male  27.0    no
# ..      ...     ...   ...   ...
# 118       3    male   NaN    no
# 388       3  female  31.0    no
# 494       3  female   NaN    no
# 29        3    male  21.0    no
# 247       3  female  29.0   yes
#
# [177 rows x 4 columns]

# %%
ytrain
# Out:
#      survived
# 603         0
# 433         0
# 360         1
# 355         0
# 81          0
# ..        ...
# 106         0
# 270         0
# 860         0
# 435         1
# 102         0
#
# [706 rows x 1 columns]

# %%
ytest
# Out:
#      survived
# 44          1
# 806         0
# 720         0
# 660         0
# 878         0
# ..        ...
# 118         0
# 388         0
# 494         0
# 29          0
# 247         1
#
# [177 rows x 1 columns]
